# %%
import pandas as pd
import seaborn as sns
from collections import namedtuple
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
Age : Idade do Paciente

Sex : Genero do Paciente
    
cp : Tipo de dor no peito tipo de valor 1: Típico Angina, Valor 2: Angina Atípico Valor 3: Dor não anginosa Valor 4: Assitomática

exang: Exercício que induziu Angina (1 = sim; 0 = não)

caa: Número de vasos sanguineos (0-4)

trtbps : Pressão sanguinea em repouso

chol : Colesterol em miligramas

fbs : (quantidade de açúcar no sangue > 120 mg/dl) (1 = verdade; 0 = falso)

rest_ecg : Eletrocardiograma em repouso
    
thalach : Frequência cardiaca máxima
# Out:
#   Cell In[3], line 1
#     Age : Idade do Paciente
#                 ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df['exng'].value_counts()
# Out:
# exng
# 0    204
# 1     99
# Name: count, dtype: int64

# %%
df.shape

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
sns.countplot(x=df['sex'])
plt.xticks([0,1],['Feminino', 'Masculino'])
plt.show()

# %%
df['age'].value_counts()
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 60    11
# 44    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 65     8
# 43     8
# 45     8
# 55     8
# 42     8
# 61     8
# 53     8
# 46     7
# 48     7
# 66     7
# 50     7
# 49     5
# 47     5
# 70     4
# 39     4
# 35     4
# 68     4
# 38     3
# 71     3
# 40     3
# 69     3
# 34     2
# 37     2
# 29     1
# 74     1
# 76     1
# 77     1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df['output'].value_counts()
# Out:
# output
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
##Quem são os mais afetados com problemas cardiaco, mais velhos, quem faz ou não exercícios?
##Com qual dos dois gêneros temos mais problemas cardíacos, mulheres ou homens?
##Como podemos evitar problemas cardiacos com o grupo de pessoa mais afetado?

# %%
print(df.shape)
df.head(10).style.set_properties(**{'background-color': '#FCD805',
                           'color': 'black',
                           'border-color': 'grey'})
# Out:
# (303, 14)
# <style type="text/css">
# #T_552ba_row0_col0, #T_552ba_row0_col1, #T_552ba_row0_col2, #T_552ba_row0_col3, #T_552ba_row0_col4, #T_552ba_row0_col5, #T_552ba_row0_col6, #T_552ba_row0_col7, #T_552ba_row0_col8, #T_552ba_row0_col9, #T_552ba_row0_col10, #T_552ba_row0_col11, #T_552ba_row0_col12, #T_552ba_row0_col13, #T_552ba_row1_col0, #T_552ba_row1_col1, #T_552ba_row1_col2, #T_552ba_row1_col3, #T_552ba_row1_col4, #T_552ba_row1_col5, #T_552ba_row1_col6, #T_552ba_row1_col7, #T_552ba_row1_col8, #T_552ba_row1_col9, #T_552ba_row1_col10, #T_552ba_row1_col11, #T_552ba_row1_col12, #T_552ba_row1_col13, #T_552ba_row2_col0, #T_552ba_row2_col1, #T_552ba_row2_col2, #T_552ba_row2_col3, #T_552ba_row
ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_552ba_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_552ba_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_552ba_level0_col2" class="col_heading level0 col2" >cp</th>
#       <th id="T_552ba_level0_col3" class="col_heading level0 col3" >trtbps</th>
#       <th id="T_552ba_level0_col4" class="col_heading level0 col4" >chol</th>
#       <th id="T_552ba_level0_col5" class="col_heading level0 col5" >fbs</th>
#       <th id="T_552ba_level0_col6" class="col_heading level0 col6" >restecg</th>
#       <th id="T_552ba_level0_col7" class="col_heading level0 col7" >thalachh</th>
#       <th id="T_552ba_level0_col8" class="col_heading level0 col8" >exng</th>
#       <th id="T_552ba_level0_col9" class="col_heading level0 col9" >oldpeak</th>
#       <th id="T_552ba_level0_col10" class="col_heading level0 col10" >slp</th>
#       <th id="T_552ba_level0_col11" class="col_heading level0 col11" >caa</th>
#       <th id="T_552ba_level0_col12" class="col_heading level0 col12" >thall</th>
#       <th id="T_552ba_level0_col13" class="col_heading level0 col13" >output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_552ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_552ba_row0_col0" class="data row0 col0" >63</td>
#       <td id="T_552ba_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_552ba_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_552ba_row0_col3" class="data row0 col3" >145</td>
#       <td id="T_552ba_row0_col4" class="data row0 col4" >233</td>
#       <td id="T_552ba_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_552ba_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_552ba_row0_col7" class="data row0 col7" >150</td>
#       <td id="T_552ba_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_552ba_row0_col9" class="data row0 col9" >2.300000</td>
#       <td id="T_552ba_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_552ba_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_552ba_row0_col12" class="data row0 col12" >1</td>
#       <td id="T_552ba_row0_col13" class="data row0 col13" >1</td>
#     </tr>
#     <tr>
#       <th id="T_552ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_552ba_row1_col0" class="data row1 col0" >37</td>
#       <td id="T_552ba_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_552ba_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_552ba_row1_col3" class="data row1 col3" >130</td>
#       <td id="T_552ba_row1_col4" class="data row1 col4" >250</td>
#       <td id="T_552ba_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_552ba_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_552ba_row1_col7" class="data row1 col7" >187</td>
#       <td id="T_552ba_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_552ba_row1_col9" class="data row1 col9" >3.500000</td>
#       <td id="T_552ba_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_552ba_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_552ba_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_552ba_row1_col13" class="data row1 col13" >1</td>
#     </tr>
#     <tr>
#       <th id="T_552ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_552ba_row2_col0" class="data row2 col0" >41</td>
#       <td id="T_552ba_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_552ba_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_552ba_row2_col3" class="data row2 col3" >130</td>
#       <td id="T_552ba_row2_col4" class="data row2 col4" >204</td>
#       <td id="T_552ba_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_552ba_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_552ba_row2_col7" class="data row2 col7" >172</td>
#       <td id="T_552ba_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_552ba_row2_col9" class="data row2 col9" >1.400000</td>
#       <td id="T_552ba_row2_col10" class="data row2 col10" >2</td>
#       <td id="T_552ba_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_552ba_row2_col12" class="data row2 col12" >2</td>
#       <td id="T_552ba_row2_col13" class="data row2 col13" >1</td>
#     </tr>
#     <tr>
#       <th id="T_552ba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_552ba_row3_col0" class="data row3 col0" >56</td>
#       <td id="T_552ba_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_552ba_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_552ba_row3_col3" class="data row3 col3" >120</td>
#       <td id="T_552ba_row3_col4" class="data row3 col4" >236</td>
#       <td id="T_552ba_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_552ba_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_552ba_row3_col7" class="data row3 col7" >178</td>
#       <td id="T_552ba_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_552ba_row3_col9" class="data row3 col9" >0.800000</td>
#       <td id="T_552ba_row3_col10" class="data row3 col10" >2

# %%
columns_interface = ['age', 'cp', 'chol']

# %%
def dist_box(df, feature=None, size=(25, 5)):
    fig, (ax_hist, ax_box) = plt.subplots(nrows=2, figsize=size, gridspec_kw={"height_ratios": (.8, .2)})

    sns.boxplot(df[feature], orient='h', color='b', ax=ax_box)
    ax_box.set_xticks([])
    ax_box.set_yticks([])
    sns.histplot(df[feature], bins=30, color='b', ax=ax_hist)
    ax_hist.set_xlabel('')
    plt.suptitle(feature, y=1.02, fontsize=16)
    plt.tight_layout()

# %%
df[columns_interface].describe()
# Out:
#               age          cp        chol
# count  303.000000  303.000000  303.000000
# mean    54.366337    0.966997  246.264026
# std      9.082101    1.032052   51.830751
# min     29.000000    0.000000  126.000000
# 25%     47.500000    0.000000  211.000000
# 50%     55.000000    1.000000  240.000000
# 75%     61.000000    2.000000  274.500000
# max     77.000000    3.000000  564.000000

# %%
for features in columns_interface:
    ax = df.plot.hist(figsize=(7, 4))

# %%
fig, axes = plt.subplots(1, 2, figsize=(17, 6), dpi=200)
sns.countplot(y=df['cp'], ax=axes[0])
axes[0].set_title('Dor no peito (cp)')
sns.countplot(x=df['age'], ax=axes[1])
axes[1].set_title('Idade')
plt.tight_layout()
plt.show()

# %%
sns.histplot(df['age'],bins=20)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(17, 6), dpi=300)
sns.countplot(y=df['age'], ax=axes[0])
axes[0].set_title('Dor no peito (cp)')
sns.histplot(df['fbs'])
axes[1].set_title('Quantidade de açúcar no sangue')
plt.tight_layout()
plt.show()

# %%
g = sns.FacetGrid(df, hue="sex",aspect=2)
g.map(sns.kdeplot, 'trtbps', fill=True)
plt.legend(labels=['Masculino', 'Feminino'])
plt.show()
# Out:
# C:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
cate_val=[]
cont_val=[]

for column in df.columns:
    if df[column].nunique() <=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exng', 'slp', 'caa', 'thall', 'output']

# %%
cont_val
# Out:
# ['age', 'trtbps', 'chol', 'thalachh', 'oldpeak']

# %%
df.hist(cont_val,figsize=(13,9))
plt.show()

# %%
sns.countplot(x=df['cp'])
plt.xticks([0,1,2,3],['angina típica', 'angina atípica', 'dor no peito atípica', 'assintomática'])
plt.xticks(rotation=0)
plt.show()

# %%
graph = plt.figure(figsize=(10,10))
cat_vs_heartattack(df,catagorical_features[:-1],target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[156], line 2
#       1 graph = plt.figure(figsize=(10,10))
# ----> 2 cat_vs_heartattack(df,catagorical_features[:-1],target)
#
# NameError: name 'cat_vs_heartattack' is not defined
